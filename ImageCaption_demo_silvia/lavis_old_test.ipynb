# %%
import torch
from PIL import Image

from lavis.models import load_model_and_preprocess
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-db1b7775384b> in <module>
#       2 from PIL import Image
#       3
# ----> 4 from lavis.models import load_model_and_preprocess
#
# ModuleNotFoundError: No module named 'lavis'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install lavis-unofficial
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lavis-unofficial
#   Downloading lavis-unofficial-0.1.10.tar.gz (189 kB)
#      |████████████████████████████████| 189 kB 9.0 MB/s
# Collecting contexttimer
#   Downloading contexttimer-0.3.3.tar.gz (4.9 kB)
# Collecting decord
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 31.5 MB/s
# Collecting einops>=0.4.1
#   Downloading einops-0.6.0-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 406 kB/s
# Collecting fairscale==0.4.4
#   Downloading fairscale-0.4.4.tar.gz (235 kB)
#      |████████████████████████████████| 235 kB 51.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.5 MB/s
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      |████████████████████████████████| 42 kB 934 kB/s
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from lavis-unofficial) (7.9.0)
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.4 MB/s
# Collecting opencv-python-headless==4.5.5.64
#   Downloading opencv_python_headless-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (47.8 MB)
#      |████████████████████████████████| 47.8 MB 1.7 MB/s
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from lavis-unofficial) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from lavis-unofficial) (1.3.5)
# Requirement already satisfied: plotly in /usr/local/lib/python3.8/dist-packages (from lavis-unofficial) (5.5.0)
# Collecting pre-commit
#   Downloading pre_commit-2.21.0-py2.py3-none-any.whl (201 kB)
#      |████████████████████████████████| 201 kB 41.5 MB/s
# Collecting python-magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.8/dist-packages (from lavis-unofficial) (0.18.3)
# Collecting streamlit
#   Downloading streamlit-1.16.0-py2.py3-none-any.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 32.7 MB/s
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 37.9 MB/s
# Collecting torch==1.10.0
#   Downloading torch-1.10.0-cp38-cp38-manylinux1_x86_64.whl (881.9 MB)
#      |██████████████████████████████▎ | 834.1 MB 1.2 MB/s eta 0:00:40tcmalloc: large alloc 1147494400 bytes == 0x231c000 @  0x7f691877d615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |████████████████████████████████| 881.9 MB 3.0 kB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from lavis-unofficial) (0.14.0+cu116)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from lavis-unofficial) (4.64.1)
# Collecting transformers<4.22.0,>=4.15.0
#   Downloading transformers-4.21.3-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 27.3 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.8/dist-packages (from opencv-python-headless==4.5.5.64->lavis-unofficial) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.10.0->lavis-unofficial) (4.4.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 55.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers<4.22.0,>=4.15.0->lavis-unofficial) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 53.7 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers<4.22.0,>=4.15.0->lavis-unofficial) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers<4.22.0,>=4.15.0->lavis-unofficial) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers<4.22.0,>=4.15.0->lavis-unofficial) (3.8.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->lavis-unofficial) (3.0.9)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from ftfy->lavis-unofficial) (0.2.5)
# Collecting portalocker
#   Downloading portalocker-2.6.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->lavis-unofficial) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->lavis-unofficial) (57.4.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 38.0 MB/s
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->lavis-unofficial) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->lavis-unofficial) (2.0.10)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->lavis-unofficial) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->lavis-unofficial) (5.7.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->lavis-unofficial) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->lavis-unofficial) (2.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->lavis-unofficial) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->lavis-unofficial) (1.15.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 56.8 MB/s
# Requirement already satisfied: kaggle in /usr/local/lib/python3.8/dist-packages (from opendatasets->lavis-unofficial) (1.5.12)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from opendatasets->lavis-unofficial) (7.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.8/dist-packages (from kaggle->opendatasets->lavis-unofficial) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle->opendatasets->lavis-unofficial) (2022.12.7)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle->opendatasets->lavis-unofficial) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle->opendatasets->lavis-unofficial) (7.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->lavis-unofficial) (2022.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->lavis-unofficial) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly->lavis-unofficial) (8.1.0)
# Collecting virtualenv>=20.10.0
#   Downloading virtualenv-20.17.1-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 35.3 MB/s
# Collecting nodeenv>=0.11.1
#   Downloading nodeenv-1.7.0-py2.py3-none-any.whl (21 kB)
# Collecting identify>=1.0.0
#   Downloading identify-2.5.11-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 5.7 MB/s
# Collecting cfgv>=2.0.0
#   Downloading cfgv-3.3.1-py2.py3-none-any.whl (7.3 kB)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 53.5 MB/s
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv>=20.10.0->pre-commit->lavis-unofficial) (2.6.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle->opendatasets->lavis-unofficial) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<4.22.0,>=4.15.0->lavis-unofficial) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers<4.22.0,>=4.15.0->lavis-unofficial) (2.10)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->lavis-unofficial) (2.9.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->lavis-unofficial) (7.1.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image->lavis-unofficial) (1.4.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->lavis-unofficial) (2.8.8)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image->lavis-unofficial) (3.2.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image->lavis-unofficial) (1.7.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.8/dist-packages (from scikit-image->lavis-unofficial) (2022.10.10)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->lavis-unofficial) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->lavis-unofficial) (1.4.4)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.8/dist-packages (from streamlit->lavis-unofficial) (1.5.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.8/dist-packages (from streamlit->lavis-unofficial) (5.1.0)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->lavis-unofficial) (6.0.4)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->lavis-unofficial) (4.2.0)
# Collecting blinker>=1.0.0
#   Downloading blinker-1.5-py2.py3-none-any.whl (12 kB)
# Collecting semver
#   Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Collecting validators>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->lavis-unofficial) (9.0.0)
# Collecting watchdog
#   Downloading watchdog-2.2.1-py3-none-manylinux2014_x86_64.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.9 MB/s
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 54.5 MB/s
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 49.8 MB/s
# Requirement already satisfied: protobuf<4,>=3.12 in /usr/local/lib/python3.8/dist-packages (from streamlit->lavis-unofficial) (3.19.6)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.8/dist-packages (from streamlit->lavis-unofficial) (5.2.0)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.30-py3-none-any.whl (184 kB)
#      |████████████████████████████████| 184 kB 52.1 MB/s
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from streamlit->lavis-unofficial) (0.10.2)
# Collecting rich>=10.11.0
#   Downloading rich-13.0.0-py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 53.5 MB/s
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->lavis-unofficial) (4.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->lavis-unofficial) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->lavis-unofficial) (0.12.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from altair>=3.2.0->streamlit->lavis-unofficial) (2.11.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=1.4->streamlit->lavis-unofficial) (3.11.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->lavis-unofficial) (0.19.2)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->lavis-unofficial) (5.10.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit->lavis-unofficial) (22.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->altair>=3.2.0->streamlit->lavis-unofficial) (2.0.1)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 6.5 MB/s
# Collecting torchvision
#   Downloading torchvision-0.14.1-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
#      |████████████████████████████████| 24.2 MB 1.7 MB/s
#   Downloading torchvision-0.14.0-cp38-cp38-manylinux1_x86_64.whl (24.3 MB)
#      |████████████████████████████████| 24.3 MB 1.4 MB/s
#   Downloading torchvision-0.13.1-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 1.1 MB/s
#   Downloading torchvision-0.13.0-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 1.2 MB/s
#   Downloading torchvision-0.12.0-cp38-cp38-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 1.2 MB/s
#   Downloading torchvision-0.11.3-cp38-cp38-manylinux1_x86_64.whl (23.2 MB)
#      |████████████████████████████████| 23.2 MB 1.4 MB/s
#   Downloading torchvision-0.11.2-cp38-cp38-manylinux1_x86_64.whl (23.3 MB)
#      |████████████████████████████████| 23.3 MB 1.6 MB/s
#   Downloading torchvision-0.11.1-cp38-cp38-manylinux1_x86_64.whl (23.3 MB)
#      |████████████████████████████████| 23.3 MB 1.5 MB/s
# Building wheels for collected packages: lavis-unofficial, fairscale, contexttimer, iopath, antlr4-python3-runtime, validators
#   Building wheel for lavis-unofficial (setup.py) ... done
#   Created wheel for lavis-unofficial: filename=lavis_unofficial-0.1.10-py3-none-any.whl size=321297 sha256=0fc9bd1b4cc53ef9e174a1648deb5dd35a0d39fcd782d5243052a93175744080
#   Stored in directory: /root/.cache/pip/wheels/79/c2/d4/2f2cb4e387a588e88c176a87e0a44f12dc213b60cecc88fdee
#   Building wheel for fairscale (PEP 517) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.4-py3-none-any.whl size=292864 sha256=7cb049fc551e69146aa7fc86aa94a1caf1d876fb9b754e9bac2b4f75c53ef46f
#   Stored in directory: /root/.cache/pip/wheels/b3/c3/6e/3fca67aaef3657c2266e9ee439b54f534f05967cd8774cc65b
#   Building wheel for contexttimer (setup.py) ... done
#   Created wheel for contexttimer: filename=contexttimer-0.3.3-py3-none-any.whl size=5818 sha256=6cd69a0afd6d6d7100555b5c203d9fa844e0d59f82c808968293994d8a5f7c5d
#   Stored in directory: /root/.cache/pip/wheels/70/dd/09/4924e45dc5912f71b971b6790958b5e82f88c9db95a7cb4969
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=6145cc9fb42d1b8b454f7a9763c074f7f1bd7113c25f9a3b701a9f3937e11ddf
#   Stored in directory: /root/.cache/pip/wheels/89/3e/24/0f349c0b2eeb6965903035f3b00dbb5c9bea437b4a2f18d82c
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=3075935b6c3ef47c139ca4245532b10448afc38492e3bc021ac5e3fa823edc9b
#   Stored in directory: /root/.cache/pip/wheels/b1/a3/c2/6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19581 sha256=c1d11a17988dac709c4e9e7298dbb79fbee30e1e7ff0e67d7682739c4946effe
#   Stored in directory: /root/.cache/pip/wheels/19/09/72/3eb74d236bb48bd0f3c6c3c83e4e0c5bbfcbcad7c6c3539db8
# Successfully built lavis-unofficial fairscale contexttimer iopath antlr4-python3-runtime validators
# Installing collected packages: smmap, torch, gitdb, distlib, commonmark, watchdog, virtualenv, validators, torchvision, tokenizers, semver, rich, pympler, pydeck, portalocker, nodeenv, jedi, identify, huggingface-hub, gitpython, cfgv, blinker, antlr4-python3-runtime, transformers, timm, streamlit, python-magic, pre-commit, opendatasets, opencv-python-headless, omegaconf, iopath, ftfy, fairscale, einops, decord, contexttimer, lavis-unofficial
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.0+cu116
#     Uninstalling torchvision-0.14.0+cu116:
#       Successfully uninstalled torchvision-0.14.0+cu116
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.6.0.66
#     Uninstalling opencv-python-headless-4.6.0.66:
#       Successfully uninstalled opencv-python-headless-4.6.0.66
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.10.0 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.10.0 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 blinker-1.5 cfgv-3.3.1 commonmark-0.9.1 contexttimer-0.3.3 decord-0.6.0 distlib-0.3.6 einops-0.6.0 fairscale-0.4.4 ftfy-6.1.1 gitdb-4.0.10 gitpython-3.1.30 huggingface-hub-0.11.1 identify-2.5.11 iopath-0.1.10 jedi-0.18.2 lavis-unofficial-0.1.10 nodeenv-1.7.0 omegaconf-2.3.0 opencv-python-headless-4.5.5.64 opendatasets-0.1.22 portalocker-2.6.0 pre-commit-2.21.0 pydeck-0.8.0 pympler-1.0.1 python-magic-0.4.27 rich-13.0.0 semver-2.13.0 smmap-5.0.0 streamlit-1.16.0 timm-0.4.12 tokenizers-0.12.1 torch-1.10.0 torchvision-0.11.1 transformers-4.21.3 validators-0.20.0 virtualenv-20.17.1 watchdog-2.2.1

# %%
import torch
from PIL import Image

from lavis.models import load_model_and_preprocess
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-db1b7775384b> in <module>
#       2 from PIL import Image
#       3
# ----> 4 from lavis.models import load_model_and_preprocess
#
# /usr/local/lib/python3.8/dist-packages/lavis/__init__.py in <module>
#      14
#      15 #from lavis.datasets.builders import *
# ---> 16 from lavis.models import *
#      17 from lavis.processors import *
#      18 #from lavis.tasks import *
#
# /usr/local/lib/python3.8/dist-packages/lavis/models/__init__.py in <module>
#      38 from lavis.models.gpt_models.gpt_dialogue import GPTDialogue
#      39
# ---> 40 from lavis.processors.base_processor import BaseProcessor
#      41
#      42
#
# /usr/local/lib/python3.8/dist-packages/lavis/processors/__init__.py in <module>
#       8 from lavis.processors.base_processor import BaseProcessor
#       9
# ---> 10 from lavis.processors.alpro_processors import (
#      11     AlproVideoTrainProcessor,
#      12     AlproVideoEvalProcessor,
#
# /usr/local/lib/python3.8/dist-packages/lavis/processors/alpro_processors.py in <module>
#       8 import torch
#       9 from lavis.common.registry import registry
# ---> 10 from lavis.datasets.data_utils import load_video
#      11 from lavis.processors import transforms_video
#      12 from lavis.processors.base_processor import BaseProcessor
#
# /usr/local/lib/python3.8/dist-packages/lavis/datasets/data_utils.py in <module>
#      14
#      15 import decord
# ---> 16 import webdataset as wds
#      17 import numpy as np
#      18 import torch
#
# ModuleNotFoundError: No module named 'webdataset'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install webdataset
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting webdataset
#   Downloading webdataset-0.2.31-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 2.8 MB/s
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from webdataset) (6.0)
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from webdataset) (1.21.6)
# Installing collected packages: braceexpand, webdataset
# Successfully installed braceexpand-0.1.7 webdataset-0.2.31

# %%
import torch
from PIL import Image

from lavis.models import load_model_and_preprocess
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-db1b7775384b> in <module>
#       2 from PIL import Image
#       3
# ----> 4 from lavis.models import load_model_and_preprocess
#
# /usr/local/lib/python3.8/dist-packages/lavis/__init__.py in <module>
#      14
#      15 #from lavis.datasets.builders import *
# ---> 16 from lavis.models import *
#      17 from lavis.processors import *
#      18 #from lavis.tasks import *
#
# AttributeError: module 'lavis.models' has no attribute 'CLIP'

# %%
import torch
from PIL import Image

import lavis.models
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-838f652f2829> in <module>
#       2 from PIL import Image
#       3
# ----> 4 import lavis.models
#
# /usr/local/lib/python3.8/dist-packages/lavis/__init__.py in <module>
#      14
#      15 #from lavis.datasets.builders import *
# ---> 16 from lavis.models import *
#      17 from lavis.processors import *
#      18 #from lavis.tasks import *
#
# AttributeError: module 'lavis.models' has no attribute 'CLIP'

# %%
import torch
from PIL import Image

import lavis.models
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-838f652f2829> in <module>
#       2 from PIL import Image
#       3
# ----> 4 import lavis.models
#
# ModuleNotFoundError: No module named 'lavis'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install lavis.models
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement lavis.models (from versions: none)
# ERROR: No matching distribution found for lavis.models
