# %% [markdown]
# # BLIP: Inference Demo
#  - [Image Captioning](#Image-Captioning)
#  - [VQA](#VQA)
#  - [Feature Extraction](#Feature-Extraction)
#  - [Image Text Matching](#Image-Text-Matching)

# %%
# install requirements
import sys
if 'google.colab' in sys.modules:
    print('Running in Colab.')
    # !pip3 install transformers==4.15.0 timm==0.4.12 fairscale==0.4.4
    # !git clone https://github.com/salesforce/BLIP
    # %cd BLIP
# Out:
# Running in Colab.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.15.0
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 32.6 MB/s
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 32.1 MB/s
# Collecting fairscale==0.4.4
#   Downloading fairscale-0.4.4.tar.gz (235 kB)
#      |████████████████████████████████| 235 kB 78.6 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.15.0) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 78.5 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers==4.15.0) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.15.0) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers==4.15.0) (3.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers==4.15.0) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers==4.15.0) (21.3)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 67.2 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 88.6 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers==4.15.0) (4.64.1)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.8/dist-packages (from timm==0.4.12) (1.13.0+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.8/dist-packages (from timm==0.4.12) (0.14.0+cu116)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.15.0) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers==4.15.0) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.15.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.15.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.15.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.15.0) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.15.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.15.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.15.0) (1.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.8/dist-packages (from torchvision->timm==0.4.12) (7.1.2)
# Building wheels for collected packages: fairscale, sacremoses
#   Building wheel for fairscale (PEP 517) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.4-py3-none-any.whl size=292864 sha256=8d3514508a828375b046a6f520513645d7f0ce208aa0d16dd03647afb0777f6c
#   Stored in directory: /root/.cache/pip/wheels/b3/c3/6e/3fca67aaef3657c2266e9ee439b54f534f05967cd8774cc65b
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=f432d114e50098d24bd40ae1b31c9bf6fc5da67e179fefb632d585f437869c19
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built fairscale sacremoses
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers, timm, fairscale
# Successfully installed fairscale-0.4.4 huggingface-hub-0.11.1 sacremoses-0.0.53 timm-0.4.12 tokenizers-0.10.3 transformers-4.15.0
# Cloning into 'BLIP'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (136/136), done.
# remote: Total 274 (delta 151), reused 228 (delta 135), pack-reused 0
# Receiving objects: 100% (274/274), 7.03 MiB | 40.47 MiB/s, done.
# Resolving deltas: 100% (151/151), done.
# /content/BLIP

# %%
from PIL import Image
import requests
import torch
from torchvision import transforms
from torchvision.transforms.functional import InterpolationMode

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def load_demo_image(image_size,device):
    img_url = 'https://www.vettimes.co.uk/app/uploads/2016/12/Dec15_JS-blog-Xmas-tree_Fotolia-Afanasia_feature.jpg' 
    raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')   

    w,h = raw_image.size
    display(raw_image.resize((w//5,h//5)))
    
    transform = transforms.Compose([
        transforms.Resize((image_size,image_size),interpolation=InterpolationMode.BICUBIC),
        transforms.ToTensor(),
        transforms.Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711))
        ]) 
    image = transform(raw_image).unsqueeze(0).to(device)   
    return image

# %% [markdown]
# # Image Captioning
# Perform image captioning using finetuned BLIP model

# %%
from models.blip import blip_decoder

image_size = 384
image = load_demo_image(image_size=image_size, device=device)

model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth'
    
model = blip_decoder(pretrained=model_url, image_size=image_size, vit='base')
model.eval()
model = model.to(device)

with torch.no_grad():
    # beam search
    caption = model.generate(image, sample=False, num_beams=3, max_length=20, min_length=5) 
    # nucleus sampling
    # caption = model.generate(image, sample=True, top_p=0.9, max_length=20, min_length=5) 
    print('caption: '+caption[0])
# Out:
# <PIL.Image.Image image mode=RGB size=240x126 at 0x7FB10DBB30A0>
# reshape position embedding from 196 to 576
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a cat hanging on a christmas tree

# %% [markdown]
# # VQA
# Perform visual question answering using finetuned BLIP model

# %%
from models.blip_vqa import blip_vqa

image_size = 480
image = load_demo_image(image_size=image_size, device=device)     

model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_vqa_capfilt_large.pth'
    
model = blip_vqa(pretrained=model_url, image_size=image_size, vit='base')
model.eval()
model = model.to(device)

question = 'what is the detailed description of the scene?'

with torch.no_grad():
    answer = model(image, question, train=False, inference='generate') 
    print('answer: '+answer[0])
# Out:
# <PIL.Image.Image image mode=RGB size=240x126 at 0x7FB0D08F65E0>
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_vqa_capfilt_large.pth
# answer: cat in tree

# %% [markdown]
# # Feature Extraction

# %%
from models.blip import blip_feature_extractor

image_size = 224
image = load_demo_image(image_size=image_size, device=device)     

model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base.pth'
    
model = blip_feature_extractor(pretrained=model_url, image_size=image_size, vit='base')
model.eval()
model = model.to(device)

caption = 'a woman sitting on the beach with a dog'

multimodal_feature = model(image, caption, mode='multimodal')[0,0]
image_feature = model(image, caption, mode='image')[0,0]
text_feature = model(image, caption, mode='text')[0,0]
# Out:
# <PIL.Image.Image image mode=RGB size=240x126 at 0x7FB10E4C6F10>
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base.pth

# %% [markdown]
# # Image-Text Matching

# %%
from models.blip_itm import blip_itm

image_size = 384
image = load_demo_image(image_size=image_size,device=device)

model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_retrieval_coco.pth'
    
model = blip_itm(pretrained=model_url, image_size=image_size, vit='base')
model.eval()
model = model.to(device='cpu')

caption = 'a woman sitting on the beach with a cat'

print('text: %s' %caption)

itm_output = model(image,caption,match_head='itm')
itm_score = torch.nn.functional.softmax(itm_output,dim=1)[:,1]
print('The image and text is matched with a probability of %.4f'%itm_score)

itc_score = model(image,caption,match_head='itc')
print('The image feature and text feature has a cosine similarity of %.4f'%itc_score)
# Out:
# <PIL.Image.Image image mode=RGB size=240x126 at 0x7FB1908F79D0>
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_retrieval_coco.pth
# text: a woman sitting on the beach with a cat
# The image and text is matched with a probability of 0.0000
# The image feature and text feature has a cosine similarity of 0.2054
